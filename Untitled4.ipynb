# %% [markdown]
# # Task: Prediction using Decision Tree Algorithm (IRIS DATASET)

# %% [raw]
# Author: Prateek Singh
# ***The Sparks Foundation***

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("C:/Users/prate/Downloads/Iris.csv")

# %%
df=df.drop('Id', axis=1)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### Dataset Visualisation Using Visualisation Tools

# %%
#FACEGRID Plot of "SepalLengthCm Vs SepalWidthCm"
sns.FacetGrid(df, hue="Species", height=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %%
#FACEGRID Plot of "PetalLengthCm Vs PetalWidthCm"
sns.FacetGrid(df, hue="Species", height=5) \
   .map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
   .add_legend()

# %%
#Violin Plot of PetalLengthCm
sns.violinplot(x="Species", y="PetalLengthCm", data=df, size=6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
#Violin Plot of SepalLengthCm
sns.violinplot(x="Species", y="SepalLengthCm", data=df, size=6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
#Violin Plot of SepalWidthCm
sns.violinplot(x="Species", y="SepalWidthCm", data=df, size=6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
#Violin Plot of PetalWidthCm
sns.violinplot(x="Species", y="PetalWidthCm", data=df, size=6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# ### Training and Predicting the model

# %%
#Dividing the data for training and testing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
# Seperating the data into dependent and independent variables
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Decision Tree's model
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

classifier = DecisionTreeClassifier()

clf=classifier.fit(X_train, y_train)

#Decision Tree Classifer Created

# %%
y_pred = classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]

# %%
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,y_test))
# Out:
# accuracy is 1.0

# %% [markdown]
# # Visualization of Decision Tree by:

# %% [markdown]
# ### 1.Text Representation

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_2 <= 2.35
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.35
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica

# %% [markdown]
# ### 2. Plot Tree

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf,feature_names=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"],  
                   class_names=["Iris-setosa", "Iris-versicolor","Iris-virginica"],
                   filled=True)

# %% [markdown]
# ### 3. Graphviz

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"],  
                                class_names=["Iris-setosa", "Iris-versicolor","Iris-virginica"],
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph
